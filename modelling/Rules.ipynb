# %% [markdown]
# ### To Do
#
# 1. Prepare dataset to label (yanjean) [done]
#     - Use some already existing yelp reviews model to identify negative reviews
#     - Filter out 500 of it
#     - Run all the processing on these 500
#     - Randomly split these into 3-1-1 for train-test-val
#
#
# 2. Preprocessing - Functions [done]
#     - Remove punctuations
#     - Remove ALL numbers
#     - Remove empty strings and new lines
#
#
# 3. Rules Before Filter - Functions
#     - Add negation identification
#     - Add emoji identification (sean)
#
#
# 4. Rules After Filter - Functions [done]
#     - Remove nouns
#     - Remove stopwords
#     - If the entire phrase is stopwords, remove row

# %% [markdown]
# ### Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
import ast
import os
import en_core_web_sm
nlp = en_core_web_sm.load()
import re
import nltk
from nltk.corpus import stopwords
nltk.download('punkt')
from nltk.tokenize import word_tokenize  
import string
from string import digits
# Out:
# [nltk_data] Downloading package punkt to /Users/risalim/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# ### Load Data

# %%
# aspects
aspects_df = pd.read_csv("df1.csv")
aspects_df.head()
# Out:
#                                               review  \
# 0  The malabar fish curry here is yummmm. Must tr...
# 1  I like it that the handmade egg noodles were s...
# 2  Delectable noodles n its really gd ! Nothing b...
# 3  For wanton Noodles + zichar options. Can't com...
# 4  There is a new ENG WONTON NOODLE at novena! Ne...
#
#                                              aspects  \
# 0     {'food': ['chicken', 'rice', 'curry', 'fish']}
# 1              {'food': ['noodles', 'egg', 'sauce']}
# 2                     {'food': ['wonton', 'noodle']}
# 3                              {'food': ['noodles']}
# 4  {'food': ['water', 'pancake', 'meat', 'noodle'...
#
#                                             new_food  \
# 0  ['malabar fish curry', 'chicken dum biriyani',...
# 1  ['handmade egg', 'bite', 'mixing', 'special fi...
# 2  ['nothing but savoury', 'nothing', 'savoury', ...
# 3                       ['wanton', 'zichar', 'spot']
# 4  ['novena', 'pancake', 'came', 'regular dry wan...
#
#                                          aspects_new
# 0  {'food': ['chicken', 'rice', 'curry', 'fish', ...
# 1  {'food': ['noodles', 'egg', 'sauce', 'handmade...
# 2  {'food': ['wonton', 'noodle', 'nothing but sav...
# 3  {'food': ['noodles', 'wanton', 'zichar', 'spot']}
# 4  {'food': ['water', 'pancake', 'meat', 'noodle'...

# %%
# aspect lists
food_list = list(pd.read_csv("./aspects/food.csv")['food'].astype(str))
time_list = list(pd.read_csv("./aspects/time.csv")['time'].astype(str))
price_list = list(pd.read_csv("./aspects/price.csv")['price'].astype(str))
portion_list = list(pd.read_csv("./aspects/portion.csv")['portion'].astype(str))
service_list = list(pd.read_csv("./aspects/service.csv")['service'].astype(str))
ambience_list = list(pd.read_csv("./aspects/ambience.csv")['ambience'].astype(str))

# %%
all_aspects = food_list + time_list + price_list + portion_list + service_list + ambience_list

# %% [markdown]
# ### Functions

# %%
'''
description: get the unique synonyms for each aspect 
input: dataframe
output: dataframe (saved as csv)
'''
def get_all_aspects(df) :
    food = []
    time = []
    price = []
    portion = []
    service = []
    ambience = []
    for row in range(0, len(df)) :
        # turn each aspects string into dictionary
        row_aspects_dict = ast.literal_eval(df['aspects'][row])
        # get the aspect keys
        row_aspects_keys = list(row_aspects_dict.keys())
        for key in row_aspects_keys :
            if key == 'food' :
                for value in row_aspects_dict['food'] :
                    if value not in food :
                        food.append(str(value))
            elif key == 'time' :
                for value in row_aspects_dict['time'] :
                    if value not in time :
                        time.append(str(value))
            elif key == 'price' :
                for value in row_aspects_dict['price'] :
                    if value not in price :
                        price.append(str(value))
            elif key == 'portion' :
                for value in row_aspects_dict['portion'] :
                    if value not in portion :
                        portion.append(str(value))
            elif key == 'service' :
                for value in row_aspects_dict['service'] :
                    if value not in service :
                        service.append(str(value))
            elif key == 'ambience' :
                for value in row_aspects_dict['ambience'] :
                    if value not in ambience :
                        ambience.append(str(value))
        print(row, "out of", len(df), "done")
    # create dataframe
    food_df = pd.DataFrame({'food': food})
    time_df = pd.DataFrame({'time': time})
    price_df = pd.DataFrame({'price': price})
    portion_df = pd.DataFrame({'portion': portion})
    service_df = pd.DataFrame({'service': service})
    ambience_df = pd.DataFrame({'ambience': ambience})
    print("dataframes created")
    # create new folder
    if not os.path.exists('./aspects') :
        os.makedirs('./aspects')
    # save as csv
    food_df.to_csv("./aspects/food.csv", index=False)
    time_df.to_csv("./aspects/time.csv", index=False)
    price_df.to_csv("./aspects/price.csv", index=False)
    portion_df.to_csv("./aspects/portion.csv", index=False)
    service_df.to_csv("./aspects/service.csv", index=False)
    ambience_df.to_csv("./aspects/ambience.csv", index=False)
    print("dataframes saved")
    
'''
description: remove numbers, empty strings, new lines from phrases
input: string
output: string
'''
def pre_processing(review) : 
    # remove numbers
    remove_digits = str.maketrans('', '', digits)
    review = review.translate(remove_digits)
    # remove new lines
    review = review.replace('\n', ' ')
    return review

'''
description: get the text, pos and tag of each word
input: text
output: dataframe
'''
def get_pos(review) :
    text = []
    pos = []
    tag = []
    doc = nlp(review)
    for token in doc:
        text.append(token.text)
        pos.append(token.pos_)
        tag.append(token.tag_)
    pos_df = pd.DataFrame({'text': text, 'pos': pos, 'tag': tag})
    return pos_df

'''
description: get aspects
input: string, list
output: list, list
'''
def get_aspects(review, pos_df, aspect_list) :
    # get aspects present in review
    aspects = list(pos_df.loc[pos_df['text'].isin(aspect_list)]['text'])
    # get sentences with aspects
    aspect_sentences = []
    # split into sentences
    sentences = review.split('.')
    for i in range(0, len(sentences)) :
        if any(aspect in sentences[i] for aspect in aspect_list) :
            aspect_sentences.append(sentences[i])
    return aspects, aspect_sentences

'''
description: get the ranges
input: list
output: list
'''
def ranges(nums):
    nums = sorted(set(nums))
    gaps = [[s, e] for s, e in zip(nums, nums[1:]) if s+1 < e]
    edges = iter(nums[:1] + sum(gaps, []) + nums[-1:])
    return list(zip(edges, edges))

'''
description: get the text where first word is target_pos and last word is aspect and vice versa
input: dataframe, list, str
output: list
'''
def pos_before_after_aspect(pos_df, aspect_list, target_pos) :
    start, end = 0, 0
    sentences = []
    positions_start = []
    positions_end = []
    filtered = []
    aspect_index = list(pos_df.loc[pos_df['text'].isin(aspect_list)].index)
    
    # adjectives before
    for i in range(0, len(aspect_index)) :
        index = aspect_index[i]
        for j in reversed(range(0, index)) :
            if pos_df['pos'][j] == target_pos or pos_df['pos'][j] == 'VERB':
                # check if there is an adv or det before then add that
                if j>1 :
                    if pos_df['pos'][j-1] == 'ADV' or pos_df['pos'][j-1] == 'DET' :
                        positions_start.append(j-1)
                        positions_end.append(index+1)
                    else :
                        positions_start.append(j)
                        positions_end.append(index+1)
                else :
                    positions_start.append(j)
                    positions_end.append(index+1)  

    # adjectives after
    for i in range(0, len(aspect_index)) :
        index = aspect_index[i]
        for j in range(index, len(pos_df)) :
            if pos_df['pos'][j] == target_pos :
                positions_start.append(index+1)
                positions_end.append(j)
            
    positions_df = pd.DataFrame({'start': positions_start, 'end': positions_end})
    positions_df = positions_df.drop_duplicates().reset_index(drop=True)
    positions_df = positions_df.sort_values(by=['start', 'end'])
    filtered_df_1 = positions_df.drop_duplicates(subset=['end'], keep='last').reset_index(drop=True)
    filtered_df = filtered_df_1.drop_duplicates(subset=['start'], keep='last').reset_index(drop=True)
    
    for i in range(0, len(filtered_df)) :
        start = filtered_df['start'][i]
        end = filtered_df['end'][i]
        if start < end and start!=0 and end!=0:
            review = pos_df['text'][start:end+1].apply(lambda x:x + ' ').sum()
            if '.' in review :
                review = review.split(".")[0]
            elif '!' in review :
                review = review.split("!")[0]
            elif '?' in review :
                review = review.split("?")[0]
            if len(review) > 0 :
                filtered.append(review)
    return filtered

'''
description: get the start and end indexes of the sentence
input: string, dataframe
output: dataframe
'''
def get_sentence_indexes(sentence, pos_df) :
    sentence_split = sentence.split(" ")
    target_pos = pos_df.loc[pos_df['text'].isin(sentence_split)]
    target_index = list(target_pos.index)
    ranges_list = ranges(target_index)
    for i in ranges_list :
        if i[0] != i[1] :
            start = i[0]
            end = i[1] + 1
            return pos_df[start:end]

def get_sentences_indexes(sentence, pos_df) :
    all_indexes = pd.DataFrame({'text':[], 'pos':[],'tag':[]})
    for i in range(0, len(sentence)) :
        pos_df_target = get_sentence_indexes(sentence[i], pos_df)
        all_indexes = pd.concat([all_indexes, pos_df_target])
    return all_indexes
        
'''
description: get the sentences from indexes
input: dataframe, dataframe
output: list
'''
def get_sentences(pos_df, pos_df_original) :
    pos_df_phrases = []
    pos_df_index = list(pos_df.index)
    ranges_list = ranges(pos_df_index)
    for i in ranges_list :
        if i[0] != i[1] :
            start = i[0]
            end = i[1] + 1
            pos_df_phrases.append(pos_df_original['text'][start:end].apply(lambda x:x + ' ').sum())
    return pos_df_phrases

'''
description: remove nouns, stopwords and punctuations from phrases
input: list, list
output: list
'''

def post_processing(phrase_list, to_remove) : 
    new_phrase_list = []
    for phrase in phrase_list :
        pos_df = get_pos(phrase)
        nouns = list(pos_df.loc[pos_df['pos']=='NOUN']['text'])
        #to_remove += nouns
        word_tokens = word_tokenize(phrase)
        new_phrase_list.append([w for w in word_tokens if not w in to_remove])
    return new_phrase_list

'''
description: apply functions to aspect
input: str, dataframe, list
output: list
'''
def process_review_aspect(review, pos_df, aspect_list, to_remove) :
    aspects, sentence = get_aspects(review, pos_df, aspect_list)
    sentence_new = pos_before_after_aspect(pos_df, aspects, 'ADJ')
    aspect_pos = get_sentences_indexes(sentence_new, pos_df)
    aspect_pos = aspect_pos.sort_index().drop_duplicates()
    phrase_list = get_sentences(aspect_pos, pos_df)
    phrase_list_cleaned = post_processing(phrase_list, to_remove)
    return phrase_list_cleaned

'''
description: add phrase_no_noun and phrase_no_aspect
input: dataframe, list
output: dataframe
'''
def add_phrases(df, all_aspects) :
    new_phrase_no_aspect = []
    new_phrase_no_noun = []
    for i in range(0, len(df)) :
        no_aspect = []
        no_noun = []
        phrase_list = df['phrase'][i].split(', ')
        for phrase in phrase_list:
            if phrase not in all_aspects :
                no_aspect.append(phrase)
            if get_pos(phrase)['pos'][0] != 'NOUN' :
                no_noun.append(phrase)
        new_phrase_no_aspect.append(no_aspect)
        new_phrase_no_noun.append(no_noun)
    df['phrase_no_aspect'] = new_phrase_no_aspect
    df['phrase_no_noun'] = new_phrase_no_noun
    return df

'''
description: apply functions to review
input: path to dataframe
output: dataframe
'''
def process_reviews(df_path) :
    
    # for post-processing
    stop_words_to_remove = set(stopwords.words('english'))  
    stop_words_dont_remove = set(['no', 'not', 'nor']) 
    # stop_words_dont_remove = set(['no', 'not', 'nor', 'don', "don't", 'should', "should've", 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]) 
    stop_words = list(stop_words_to_remove-stop_words_dont_remove)
    punctuations = list(string.punctuation)
    to_remove = stop_words + punctuations + ["'s", "n't"]
    
    df = pd.read_csv(df_path)
    
    food_phrases = []
    time_phrases = []
    price_phrases = []
    portion_phrases = []
    service_phrases = []
    ambience_phrases = []
    
    aspect_list = []
    phrase_list = []
    restaurant_code = []
    review_title = []
    review_body = []
    account_name = []
    account_id = []
    
    for i in range(0, len(df)) :
        
        review = (str(df['review_title'][i])+str(df['review_body'][i])).lower()
        # for pre-processing
        review = pre_processing(review)
        pos_df = get_pos(review)
        
        # get phrases for each aspect
        food_phrases = process_review_aspect(review, pos_df, food_list, to_remove)
        time_phrases = process_review_aspect(review, pos_df, time_list, to_remove)
        price_phrases = process_review_aspect(review, pos_df, price_list, to_remove)
        portion_phrases = process_review_aspect(review, pos_df, portion_list, to_remove)
        service_phrases = process_review_aspect(review, pos_df, service_list, to_remove)
        ambience_phrases = process_review_aspect(review, pos_df, ambience_list, to_remove)

        # add aspects together
        if len(food_phrases) > 0 :
            for j in range(0, len(food_phrases)) :
                aspect_list.append('food')
                phrase_list.append(food_phrases[j])
                restaurant_code.append(df['restaurant_code'][i])
                review_title.append(df['review_title'][i])
                review_body.append(df['review_body'][i])
                account_name.append(df['account_name'][i])
                account_id.append(df['account_id'][i])
        if len(time_phrases) > 0 :
            for j in range(0, len(time_phrases)) :
                aspect_list.append('time')
                phrase_list.append(time_phrases[j])
                restaurant_code.append(df['restaurant_code'][i])
                review_title.append(df['review_title'][i])
                review_body.append(df['review_body'][i])
                account_name.append(df['account_name'][i])
                account_id.append(df['account_id'][i])
        if len(price_phrases) > 0 :
            for j in range(0, len(price_phrases)) :
                aspect_list.append('price')
                phrase_list.append(price_phrases[j])
                restaurant_code.append(df['restaurant_code'][i])
                review_title.append(df['review_title'][i])
                review_body.append(df['review_body'][i])
                account_name.append(df['account_name'][i])
                account_id.append(df['account_id'][i])
        if len(portion_phrases) > 0 :
            for j in range(0, len(portion_phrases)) :
                aspect_list.append('portion')
                phrase_list.append(portion_phrases[j])
                restaurant_code.append(df['restaurant_code'][i])
                review_title.append(df['review_title'][i])
                review_body.append(df['review_body'][i])
                account_name.append(df['account_name'][i])
                account_id.append(df['account_id'][i])
        if len(service_phrases) > 0 :
            for j in range(0, len(service_phrases)) :
                aspect_list.append('service')
                phrase_list.append(service_phrases[j])
                restaurant_code.append(df['restaurant_code'][i])
                review_title.append(df['review_title'][i])
                review_body.append(df['review_body'][i])
                account_name.append(df['account_name'][i])
                account_id.append(df['account_id'][i])
        if len(ambience_phrases) > 0 :
            for j in range(0, len(ambience_phrases)) :
                aspect_list.append('ambience')
                phrase_list.append(ambience_phrases[j])
                restaurant_code.append(df['restaurant_code'][i])
                review_title.append(df['review_title'][i])
                review_body.append(df['review_body'][i])
                account_name.append(df['account_name'][i])
                account_id.append(df['account_id'][i])

        #print(i, "out of", len(df), "done")
    
    # create df
    output = pd.DataFrame({'restaurant_code': restaurant_code, 'review_title': review_title, 'review_body': review_body, 'account_name': account_name, 'account_id': account_id, 'aspect': aspect_list, 'phrase': phrase_list})
    # remove empty phrases
    output = output.loc[output['phrase'].apply(lambda x: len(x)>0)]
    # set phrases to str
    output['phrase'] = output['phrase'].apply(lambda x: ", ".join(x))
    # remove duplicated rows
    output = output.drop_duplicates().reset_index(drop=True)
    # add phrase_no_noun and phrase_no_aspect
    output = add_phrases(output, all_aspects)
    
    # save as csv
    path_split = df_path.split("/")
    new_path = "/".join(path_split[:-1]) + "/unlabelled/unlabelled_" + path_split[-1]
    output.to_csv(new_path)
    
    print("saved to", new_path)
    
    return output

# %%
process_reviews("./data/train_test/reviews_test_subset.csv")
process_reviews("./data/train_test/reviews_train_subset.csv")
process_reviews("./data/train_test/reviews_validation_subset.csv")
process_reviews("./data/train_test/test_negative.csv")
process_reviews("./data/train_test/train_negative.csv")
process_reviews("./data/train_test/val_negative.csv")
# Out:
# saved to ./data/train_test/unlabelled/unlabelled_reviews_test_subset.csv
# saved to ./data/train_test/unlabelled/unlabelled_reviews_train_subset.csv
# saved to ./data/train_test/unlabelled/unlabelled_reviews_validation_subset.csv
# saved to ./data/train_test/unlabelled/unlabelled_test_negative.csv
# saved to ./data/train_test/unlabelled/unlabelled_train_negative.csv
# saved to ./data/train_test/unlabelled/unlabelled_val_negative.csv
#                     restaurant_code  \
# 0                    shimbashi-soba
# 1                    eleven-strands
# 2                    eleven-strands
# 3                    eleven-strands
# 4                    eleven-strands
# 5                    eleven-strands
# 6                    eleven-strands
# 7                    eleven-strands
# 8             kith-at-millenia-walk
# 9                         poke-doke
# 10                        poke-doke
# 11                        poke-doke
# 12             chuckwagon-bbq-grill
# 13             chuckwagon-bbq-grill
# 14             chuckwagon-bbq-grill
# 15            kith-at-millenia-walk
# 16            kith-at-millenia-walk
# 17            kith-at-millenia-walk
# 18            kith-at-millenia-walk
# 19            kith-at-millenia-walk
# 20            kith-at-millenia-walk
# 21   leon-kee-claypot-pork-rib-soup
# 22   leon-kee-claypot-pork-rib-soup
# 23                roland-restaurant
# 24                roland-restaurant
# 25                roland-restaurant
# 26                   eleven-strands
# 27                   eleven-strands
# 28                roland-restaurant
# 29                roland-restaurant
# ..                              ...
# 806                  eleven-strands
# 807                  eleven-strands
# 808           kith-at-millenia-walk
# 809           kith-at-millenia-walk
# 810           kith-at-millenia-walk
# 811           kith-at-millenia-walk
# 812           kith-at-millenia-walk
# 813           kith-at-millenia-walk
# 814           kith-at-millenia-walk
# 815           kith-at-millenia-walk
# 816      muk-bang-korean-restaurant
# 817      muk-bang-korean-restaurant
# 818      muk-bang-korean-restaurant
# 819      muk-bang-korean-restaurant
# 820      muk-bang-korean-restaurant
# 821      muk-bang-korean-restaurant
# 822      muk-bang-korean-restaurant
# 823      muk-bang-korean-restaurant
# 824      muk-bang-korean-restaurant
# 825      muk-bang-korean-restaurant
# 826      muk-bang-korean-restaurant
# 827      muk-bang-korean-restaurant
# 828             jia-le-roasted-food
# 829             jia-le-roasted-food
# 830           kith-at-millenia-walk
# 831           kith-at-millenia-walk
# 832           kith-at-millenia-walk
# 833           kith-at-millenia-walk
# 834           kith-at-millenia-walk
# 835           kith-at-millenia-walk
#
#                                           review_title  \
# 0                                             Soba Set
# 1                                    Crabmeat Linguine
# 2                                    Crabmeat Linguine
# 3                                    Crabmeat Linguine
# 4                                    Crabmeat Linguine
# 5                                    Crabmeat Linguine
# 6                                    Crabmeat Linguine
# 7                                    Crabmeat Linguine
# 8                                 Loaded Fries ($15++)
# 9                         Regular Sized Poke (2 Meats)
# 10                        Regular Sized Poke (2 Meats)
# 11                        Regular Sized Poke (2 Meats)
# 12                                       Never Again !
# 13                                       Never Again !
# 14                                       Never Again !
# 15                                Breakfast For lunch!
# 16                                Breakfast For lunch!
# 17                                Breakfast For lunch!
# 18                  Salted Caramel Chocolate Cake $8++
# 19                  Salted Caramel Chocolate Cake $8++
# 20                  Salted Caramel Chocolate Cake $8++
# 21                                          Herbal BKT
# 22                                          Herbal BKT
# 23                        Deep Fried Yam With Scallops
# 24                        Deep Fried Yam With Scallops
# 25                        Deep Fried Yam With Scallops
# 26                             Please Do Not Come Here
# 27                             Please Do Not Come Here
# 28           Drunken Prawns served in a Bamboo Basket.
# 29           Drunken Prawns served in a Bamboo Basket.
# ..                                                 ...
# 806                            Grilled Pork Chop ($24)
# 807                            Grilled Pork Chop ($24)
# 808  Lunch Specials - Chicken ($19)\n🍽\nGrilled mar...
# 809  Lunch Specials - Chicken ($19)\n🍽\nGrilled mar...
# 810  Lunch Specials - Chicken ($19)\n🍽\nGrilled mar...
# 811  Lunch Specials - Chicken ($19)\n🍽\nGrilled mar...
# 812  Lunch Specials - Chicken ($19)\n🍽\nGrilled mar...
# 813  Lunch Specials - Chicken ($19)\n🍽\nGrilled mar...
# 814  Lunch Specials - Chicken ($19)\n🍽\nGrilled mar...
# 815  Lunch Specials - Chicken ($19)\n🍽\nGrilled mar...
# 816                      For Heart-Warming Korean Stew
# 817                      For Heart-Warming Korean Stew
# 818                      For Heart-Warming Korean Stew
# 819                      For Heart-Warming Korean Stew
# 820                      For Heart-Warming Korean Stew
# 821                      For Heart-Warming Korean Stew
# 822                      For Heart-Warming Korean Stew
# 823                      For Heart-Warming Korean Stew
# 824                      For Heart-Warming Korean Stew
# 825                      For Heart-Warming Korean Stew
# 826                      For Heart-Warming Korean Stew
# 827                      For Heart-Warming Korean Stew
# 828                                      Suckling Pig.
# 829                                      Suckling Pig.
# 830                                      Chicken Steak
# 831                                      Chicken Steak
# 832                                      Chicken Steak
# 833                                      Chicken Steak
# 834                                      Chicken Steak
# 835                                      Chicken Steak
#
#                                            review_body    account_name  \
# 0                                              Not bad       Melinda S
# 1    For the price, it was definitely not worth the...     Kenneth Tay
# 2    For the price, it was definitely not worth the...     Kenneth Tay
# 3    For the price, it was definitely not worth the...     Kenneth Tay
# 4    For the price, it was definitely not worth the...     Kenneth Tay
# 5    For the price, it was definitely not worth the...     Kenneth Tay
# 6    For the price, it was definitely not worth the...     Kenneth Tay
# 7    For the price, it was definitely not worth the...     Kenneth Tay
# 8    The bolognaise sauce was average and unfortuna...     AD Munchkin
# 9    Meh. Too basic. The Salmon chunks was small an...       Abigail K
# 10   Meh. Too basic. The Salmon chunks was small an...       Abigail K
# 11   Meh. Too basic. The Salmon chunks was small an...       Abigail K
# 12   Had a steak and bangers&mash.. not worth the p...     Hiran Sidhu
# 13   Had a steak and bangers&mash.. not worth the p...     Hiran Sidhu
# 14   Had a steak and bangers&mash.. not worth the p...     Hiran Sidhu
# 15   Food was alright only and service was really b...      Yvonne Han
# 16   Food was alright only and service was really b...      Yvonne Han
# 17   Food was alright only and service was really b...      Yvonne Han
# 18   This was pretty average. Cake layers were too ...     AD Munchkin
# 19   This was pretty average. Cake layers were too ...     AD Munchkin
# 20   This was pretty average. Cake layers were too ...     AD Munchkin
# 21   Too often disappointed by small portions of me...   potato tomato
# 22   Too often disappointed by small portions of me...   potato tomato
# 23   Crispy but greasy yam. Oil was not hot enough!...             S G
# 24   Crispy but greasy yam. Oil was not hot enough!...             S G
# 25   Crispy but greasy yam. Oil was not hot enough!...             S G
# 26   The dishes here were tasteless and overcooked....    Siyu Waldorf
# 27   The dishes here were tasteless and overcooked....    Siyu Waldorf
# 28   It was average I guess, but presentation works...      Harold Koh
# 29   It was average I guess, but presentation works...      Harold Koh
# ..                                                 ...             ...
# 806  The pork chop was rather juicy, with a mix of ...    aggs & xi :D
# 807  The pork chop was rather juicy, with a mix of ...    aggs & xi :D
# 808  Generous portion of springy spaghetti aglio ol...     Judy Choong
# 809  Generous portion of springy spaghetti aglio ol...     Judy Choong
# 810  Generous portion of springy spaghetti aglio ol...     Judy Choong
# 811  Generous portion of springy spaghetti aglio ol...     Judy Choong
# 812  Generous portion of springy spaghetti aglio ol...     Judy Choong
# 813  Generous portion of springy spaghetti aglio ol...     Judy Choong
# 814  Generous portion of springy spaghetti aglio ol...     Judy Choong
# 815  Generous portion of springy spaghetti aglio ol...     Judy Choong
# 816  If you're in the east, swing by for a hearty d...  Burpple Guides
# 817  If you're in the east, swing by for a hearty d...  Burpple Guides
# 818  If you're in the east, swing by for a hearty d...  Burpple Guides
# 819  If you're in the east, swing by for a hearty d...  Burpple Guides
# 820  If you're in the east, swing by for a hearty d...  Burpple Guides
# 821  If you're in the east, swing by for a hearty d...  Burpple Guides
# 822  If you're in the east, swing by for a hearty d...  Burpple Guides
# 823  If you're in the east, swing by for a hearty d...  Burpple Guides
# 824  If you're in the east, swing by for a hearty d...  Burpple Guides
# 825  If you're in the east, swing by for a hearty d...  Burpple Guides
# 826  If you're in the east, swing by for a hearty d...  Burpple Guides
# 827  If you're in the east, swing by for a hearty d...  Burpple Guides
# 828  #burrple #6plus #food #foodporn #yum #instafoo...      Jeremy Tan
# 829  #burrple #6plus #food #foodporn #yum #instafoo...      Jeremy Tan
# 830  Stuffed Chicken Breast, Mushrooms, Black Olive...          Wen Qi
# 831  Stuffed Chicken Breast, Mushrooms, Black Olive...          Wen Qi
# 832  Stuffed Chicken Breast, Mushrooms, Black Olive...          Wen Qi
# 833  Stuffed Chicken Breast, Mushrooms, Black Olive...          Wen Qi
# 834  Stuffed Chicken Breast, Mushrooms, Black Olive...          Wen Qi
# 835  Stuffed Chicken Breast, Mushrooms, Black Olive...          Wen Qi
#
#              account_id    aspect  \
# 0             @melindas      food
# 1           @kennethtay      food
# 2           @kennethtay      food
# 3           @kennethtay      food
# 4           @kennethtay     price
# 5           @kennethtay   portion
# 6           @kennethtay   portion
# 7           @kennethtay   portion
# 8             @nomnom07      food
# 9             @abbybaby      food
# 10            @abbybaby      food
# 11            @abbybaby   portion
# 12              @HiranS      food
# 13              @HiranS     price
# 14              @HiranS     price
# 15         @yvonnehanjk      time
# 16         @yvonnehanjk     price
# 17         @yvonnehanjk   service
# 18            @nomnom07      food
# 19            @nomnom07      food
# 20            @nomnom07      food
# 21   @hungryandconfused      food
# 22   @hungryandconfused   portion
# 23               @Greey      food
# 24               @Greey      food
# 25               @Greey   portion
# 26         @siyuwaldorf      food
# 27         @siyuwaldorf      food
# 28   @thefoodexpository      food
# 29   @thefoodexpository      food
# ..                  ...       ...
# 806         @coldbuttER      food
# 807         @coldbuttER  ambience
# 808         @judychoong      food
# 809         @judychoong      food
# 810         @judychoong      food
# 811         @judychoong      food
# 812         @judychoong      food
# 813         @judychoong   portion
# 814         @judychoong   portion
# 815         @judychoong   portion
# 816      @BurppleGuides      food
# 817      @BurppleGuides      food
# 818      @BurppleGuides      food
# 819      @BurppleGuides      food
# 820      @BurppleGuides      food
# 821      @BurppleGuides      food
# 822      @BurppleGuides      food
# 823      @BurppleGuides      food
# 824      @BurppleGuides   portion
# 825      @BurppleGuides   portion
# 826      @BurppleGuides   portion
# 827      @BurppleGuides   portion
# 828               @9688      food
# 829               @9688      food
# 830             @wen_08      food
# 831             @wen_08      food
# 832             @wen_08      food
# 833             @wen_08      food
# 834             @wen_08      food
# 835             @wen_08      food
#
#                                                 phrase  \
# 0                                          setnot, bad
# 1                                          worth, buck
# 2                                             generous
# 3                      taste, somewhat, bland, lacking
# 4                                                 buck
# 5                                          worth, buck
# 6                                             generous
# 7                      taste, somewhat, bland, lacking
# 8            average, unfortunately, fries, got, soggy
# 9                                                basic
# 10                            chunks, small, not, firm
# 11                            chunks, small, not, firm
# 12                                steak, bangers, mash
# 13                                steak, bangers, mash
# 14                                  worth, price, paid
# 15                                         really, bad
# 16                           charging, service, charge
# 17                       alright, service, really, bad
# 18                                     salted, caramel
# 19                                     pretty, average
# 20                                         layers, dry
# 21                   small, portions, meat, monotonous
# 22   often, disappointed, small, portions, meat, mo...
# 23                         scallopscrispy, greasy, yam
# 24                                            not, hot
# 25                                         hot, enough
# 26                                heavy, chaota, taste
# 27              ordered, another, plate, chicken, wing
# 28                                      served, bamboo
# 29                                      drunk, seafood
# ..                                                 ...
# 806                                        beef, items
# 807                 given, popularity, place, expected
# 808  🍽, grilled, marinated, chicken, thigh, super, ...
# 809            springy, spaghetti, aglio, olio, served
# 810      mixed, green, salad, cherry, tomatoes, topped
# 811                           grated, grana, padano, 😘
# 812                            full, polishing, entire
# 813  springy, spaghetti, aglio, olio, served, mixed...
# 814                           grated, grana, padano, 😘
# 815                            full, polishing, entire
# 816  warming, korean, stewif, 're, east, swing, hea...
# 817                    flavourful, broth, comes, array
# 818                    ingredients, like, baked, beans
# 819                                    chicken, slices
# 820                                     luncheon, meat
# 821                                   straw, mushrooms
# 822                     instant, noodles, crab, sticks
# 823                                       kimchi, jeon
# 824  comes, array, ingredients, like, baked, beans,...
# 825                                     luncheon, meat
# 826                                   straw, mushrooms
# 827                     instant, noodles, crab, sticks
# 828                                     yummy, amazing
# 829                                      dinner, lunch
# 830                              chicken, steakstuffed
# 831                                  breast, mushrooms
# 832                                      black, olives
# 833                     red, cherry, brandy, reduction
# 834                                  grilled, tomatoes
# 835                                kale, walnut, salad
#
#                                       phrase_no_aspect  \
# 0                                        [setnot, bad]
# 1                                               [buck]
# 2                                                   []
# 3                           [somewhat, bland, lacking]
# 4                                               [buck]
# 5                                               [buck]
# 6                                                   []
# 7                           [somewhat, bland, lacking]
# 8                 [average, unfortunately, got, soggy]
# 9                                              [basic]
# 10                                 [chunks, not, firm]
# 11                                 [chunks, not, firm]
# 12                                     [bangers, mash]
# 13                                     [bangers, mash]
# 14                                              [paid]
# 15                                       [really, bad]
# 16                                          [charging]
# 17                              [alright, really, bad]
# 18                                            [salted]
# 19                                   [pretty, average]
# 20                                       [layers, dry]
# 21                              [portions, monotonous]
# 22         [often, disappointed, portions, monotonous]
# 23                       [scallopscrispy, greasy, yam]
# 24                                          [not, hot]
# 25                                               [hot]
# 26                                     [heavy, chaota]
# 27                     [ordered, another, plate, wing]
# 28                                            [served]
# 29                                             [drunk]
# ..                                                 ...
# 806                                            [items]
# 807                      [given, popularity, expected]
# 808  [🍽, grilled, marinated, thigh, super, really, ...
# 809                     [springy, aglio, olio, served]
# 810                          [mixed, tomatoes, topped]
# 811                         [grated, grana, padano, 😘]
# 812                          [full, polishing, entire]
# 813  [springy, aglio, olio, served, mixed, tomatoes...
# 814                         [grated, grana, padano, 😘]
# 815                          [full, polishing, entire]
# 816  [warming, korean, stewif, 're, east, swing, he...
# 817                         [flavourful, comes, array]
# 818                               [like, baked, beans]
# 819                                           [slices]
# 820                                         [luncheon]
# 821                                 [straw, mushrooms]
# 822                                  [instant, sticks]
# 823                                             [jeon]
# 824         [comes, array, like, baked, beans, slices]
# 825                                         [luncheon]
# 826                                 [straw, mushrooms]
# 827                                  [instant, sticks]
# 828                                            [yummy]
# 829                                    [dinner, lunch]
# 830                                     [steakstuffed]
# 831                                [breast, mushrooms]
# 832                                    [black, olives]
# 833                                   [red, reduction]
# 834                                [grilled, tomatoes]
# 835                                                 []
#
#                                         phrase_no_noun
# 0                                        [setnot, bad]
# 1                                              [worth]
# 2                                           [generous]
# 3                    [taste, somewhat, bland, lacking]
# 4                                                   []
# 5                                              [worth]
# 6                                           [generous]
# 7                    [taste, somewhat, bland, lacking]
# 8                 [average, unfortunately, got, soggy]
# 9                                              [basic]
# 10                          [chunks, small, not, firm]
# 11                          [chunks, small, not, firm]
# 12                                                  []
# 13                                                  []
# 14                                       [worth, paid]
# 15                                       [really, bad]
# 16                                          [charging]
# 17                              [alright, really, bad]
# 18                                            [salted]
# 19                                   [pretty, average]
# 20                                               [dry]
# 21                                 [small, monotonous]
# 22            [often, disappointed, small, monotonous]
# 23                                    [scallopscrispy]
# 24                                          [not, hot]
# 25                                       [hot, enough]
# 26                                      [heavy, taste]
# 27                                  [ordered, another]
# 28                                            [served]
# 29                                             [drunk]
# ..                                                 ...
# 806                                                 []
# 807                                  [given, expected]
# 808  [🍽, grilled, marinated, super, really, appetiz...
# 809                           [springy, aglio, served]
# 810                      [mixed, green, salad, topped]
# 811                                   [grated, padano]
# 812                          [full, polishing, entire]
# 813  [springy, aglio, served, mixed, green, salad, ...
# 814                                   [grated, padano]
# 815                          [full, polishing, entire]
# 816                     [warming, korean, 're, hearty]
# 817                         [flavourful, broth, comes]
# 818                                      [like, baked]
# 819                                                 []
# 820                                                 []
# 821                                                 []
# 822                                                 []
# 823                                                 []
# 824                               [comes, like, baked]
# 825                                                 []
# 826                                                 []
# 827                                                 []
# 828                                   [yummy, amazing]
# 829                                                 []
# 830                                     [steakstuffed]
# 831                                                 []
# 832                                    [black, olives]
# 833                                              [red]
# 834                                          [grilled]
# 835                                    [walnut, salad]
#
# [836 rows x 9 columns]

# %% [markdown]
# ### split to label

# %%
test = pd.read_csv("./data/train_test/unlabelled/unlabelled_reviews_test_subset.csv")
train = pd.read_csv("./data/train_test/unlabelled/unlabelled_reviews_train_subset.csv")
val = pd.read_csv("./data/train_test/unlabelled/unlabelled_reviews_validation_subset.csv")
test_neg = pd.read_csv("./data/train_test/unlabelled/unlabelled_test_negative.csv")
train_neg = pd.read_csv("./data/train_test/unlabelled/unlabelled_train_negative.csv")
val_neg = pd.read_csv("./data/train_test/unlabelled/unlabelled_val_negative.csv")

# %%
print('test', len(test))
print('train', len(train))
print('val', len(val))
print('test neg', len(test_neg))
print('train neg', len(train_neg))
print('val neg', len(val_neg))
# Out:
# test 2202
# train 6216
# val 2220
# test neg 838
# train neg 2133
# val neg 836

# %%
train_first = train[:3108]
train_second = train[3108:]
extra_neg = pd.concat([test_neg, train_neg, val_neg])

# %%
test.to_csv("./data/train_test/to_label/test_subset.csv", index=False)
train_first.to_csv("./data/train_test/to_label/train_first_subset.csv", index=False)
train_second.to_csv("./data/train_test/to_label/train_second_subset.csv", index=False)
val.to_csv("./data/train_test/to_label/val_subset.csv", index=False)
extra_neg.to_csv("./data/train_test/to_label/extra_neg.csv", index=False)
